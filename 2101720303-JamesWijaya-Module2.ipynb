# %%
# tuple1 = ("hardwork, 1, 5.5").split(",")
# print(tuple1[0])
# print(tuple1[1])
# print(tuple1[2])


# tuple2 = tuple1[0:2]
# print(tuple2)

# tuple3 = ("hard",("word","is"),"good")
# print(tuple3[1][1])

# number = (1,5,7,3,2)
# print(sorted(number))

# list = [1,6,7,9,10,2]
# print(list)
# print(sorted(list))
# print(sorted(list[0:3]))
# print(sorted(list)[0:3])

# list.extend([3,4])
# print(list)
# print(sorted(list))

# del(list[0])
# print(list)

# list2 = "JAMES|WIJAYA|SANTOSO".split("|")
# print(list2)
# print(list2[0] + "." + list2[2])

#lab01 Tuple
genres_tuple = ("pop", "rock", "soul", "hard rock", "soft rock",
                "R&B", "progressive rock", "disco")
print(len(genres_tuple))

print(genres_tuple[3])

print(genres_tuple[3:6])

print(genres_tuple[:2])

print(genres_tuple[7][0])

c_tuple = (-5, 1, -3)
print(sorted(c_tuple))


#lab02 List
a_list = [1, "hello", (1,2,3), True]
print(a_list)

print(a_list[1])

print(a_list[1:4])

a = [1,'a']
b = [2, 1, 'd']
print(b)
a.extend(b)
print(a)


#set
# set1 = {"pop", "rock", "soul", "hard rock"}
# album_list = ["Michael jackson", "thriller", "thriller", 1982]
# album_set = set(album_list)
# print(album_set)

# print("Michael jackson" in album_set)

# album_set2 ={"thriller","me"}

# print(album_set2.issubset(album_set))

# album_set3 = {"james","me"}

# print(album_set2.union(album_set3))
# print(album_set2.intersection(album_set3))

#lab03 set
list1 = ['rap', 'house', 'electronic music', 'rap']
set1 = set(list1)
print(set1)

A = [1, 2, 2, 1]  
B = set([1, 2, 2, 1])
print(sum(A))
print(sum(B))

#lab04 Dictionary
soundtrack_dic = {"The Bodyguard":"1992", "Saturday Night Fever":"1977"}
print(soundtrack_dic.keys())
print(soundtrack_dic.values())

album_sales_dict = {"The Bodyguard":50, "Back in Black":50, "Thriller":65}
print(album_sales_dict['Thriller'])

print(album_sales_dict.keys())
print(album_sales_dict.values())
# Out:
# dict_keys(['The Bodyguard', 'Saturday Night Fever'])
# dict_values(['1992', '1977'])
# 65
# dict_keys(['The Bodyguard', 'Back in Black', 'Thriller'])
# dict_values([50, 50, 65])
